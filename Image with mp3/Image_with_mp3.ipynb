# %%
# import the necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from scipy.io.wavfile import read

# %%
# read in the audio file
sample_rate, data = read('Cadbury-Dairy-Milk-Bodyguard-Kis.wav')

# %%
# create a figure and plot the audio waveform
fig, ax = plt.subplots()
ax.plot(data, c='b')
# Out:
# [<matplotlib.lines.Line2D at 0x20512535750>,
#  <matplotlib.lines.Line2D at 0x20512642c90>]

# %%
# Set the title and labels
ax.set_title('Audio Waveform')
ax.set_xlabel('Sample Index')
ax.set_ylabel('Amplitude')
# Out:
# Text(4.444444444444445, 0.5, 'Amplitude')

# %%
# save the figure as an image
fig.savefig('waveform.png')

# %%
# close the figure to free up resources
plt.close(fig)
